# %% [markdown]
# Cell 1

# %%
from app import app
from models import db, User, URL

# %% [markdown]
# Cell 2

# %%
with app.app_context():
    User.query.all()

# %% [markdown]
# Cell 3

# %%
with app.app_context():
    URL.query.all()
